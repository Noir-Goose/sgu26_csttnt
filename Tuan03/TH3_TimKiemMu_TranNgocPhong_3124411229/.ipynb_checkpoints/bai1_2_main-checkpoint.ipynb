# %% [markdown]
# # BÀI TOÁN MAZE

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %run bai1_2.py

# %% [raw]
# ＼（〇_ｏ）／

# %% [markdown]
# # KẾT THÚC

# %% [markdown]
# # Bài 1. Xác định các yếu tố của bài toán tìm kiếm cho các bài toán sau:
# 1. Đồ thị: Cho đồ thị có 5 đỉnh A, B, C, D được xác định bởi danh sách cạnh: A  {B,C,F}, B  {A, C, E, F}, C
#  {A,B,D, F}, D  {C, F}, E  {B,D,F}, F  {A,C,E}. Tìm đường đi từ đỉnh A đến đỉnh D.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %run bai1_1.py
# Out:
# Duong di tu A den D: A -> C -> D

# %% [markdown]
# # Kết thúc

# %% [markdown]
# THUẬT TOÁN A*KT

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %run TT_Asao.py
# Out:
# batdau:
# 1 2 3
# 4 5 6
# 7 0 8
#
# ketthuc:
# 1 2 3
# 4 8 5
# 7 6 0
#
# Solution length: 5 moves
# Animation saved to solution.gif

# %% [markdown]
# KẾT THÚC
